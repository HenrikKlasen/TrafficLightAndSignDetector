# %% [markdown]
# # Filter out only relevant pictures

# %% [markdown]
# Join BelgianTS with DriveU Traffic Lights Dataset

# %%
import os
import numpy as np
import cv2 as cv
import json
from tqdm import tqdm

def format(dtld_labels_path, data_path, mode):
    with open(dtld_labels_path) as file:
        images = json.load(file)

    images_path = data_path + "/images/" + mode
    if not os.path.exists(images_path):
        os.makedirs(images_path)

    labels_path = data_path + "/labels/" + mode
    if not os.path.exists(labels_path):
        os.makedirs(labels_path)

    for image in tqdm(images["images"]):
        image_path = "dtld/" + image["image_path"]
        image_name = os.path.splitext(os.path.basename(image_path))[0]
        if not os.path.isfile(image_path):
            continue

        # write image
        img = cv.imread(image_path, cv.IMREAD_UNCHANGED)
        img = cv.cvtColor(img, cv.COLOR_BAYER_GB2BGR)
        img = np.right_shift(img, 4)
        img = img.astype(np.uint8)
        cv.imwrite(images_path + "/" + image_name + ".jpg", img)

        # write labels
        label_file = open(images_path + "/" + image_name + ".txt", "a")
        for label in image["labels"]:
            attributes = label["attributes"]
            if attributes["relevance"] != "relevant":
                continue

            c = -1
            if attributes["state"] == "green":
                c = 21
            if attributes["state"] == "yellow":
                c = -1
            if attributes["state"] == "red":
                c = 20
            if c == -1:
                continue

            img_width = np.shape(img)[1]
            img_height = np.shape(img)[0]
            x = (label["x"] + (label["w"] / 2)) / img_width
            y = (label["y"] + (label["h"] / 2)) / img_height
            w = label["w"] / img_width
            h = label["h"] / img_height
            label_file.write(str(c) + " " + str(x) + " " + str(y)
                             + " " + str(w) + " " + str(h) + "\n")
        label_file.close()



#format(os.getcwd() + "/DTLD/v2.0/Duesseldorf.json", "./Duesseldorf", "Duesseldorf")
#format(os.getcwd() + "/DTLD/v2.0/Bochum.json", "./Bochum", "Bochum")
format(os.getcwd() + "/DTLD/v2.0/Essen.json", "./Essen", "Essen")
# Out:
# 100%|██████████| 2914/2914 [05:48<00:00,  8.37it/s]

# %% [markdown]
# Map labels to natural language signs

# %%
class_names = {
    'A13': 'Uneven road',
    'A14': 'Uneven road',
    'A15': 'Slippy road',
    'A1A': 'Steep turn left',
    'A1B': 'Steep turn right',
    'A1C': 'Multiple steep turns starting turn left',
    'A1D': 'Multiple steep turns starting turn right',
    'A23': 'Children crossing road',
    'A25': 'Bikes crossing road',
    'A29': 'Farm animals on road',
    'A31': 'Construction works',
    'A33': 'Traffic light ahead',
    'A41': 'Road closure',
    'A51': 'Danger',
    'A7A': 'Obstacle! road narrows on both sides',
    'A7B': 'Obstacle! road narrows on left',
    'A7C': 'Obstacle! road narrows on right',
    'B15A': 'Priority at next intersection',
    'B17': 'Dangerous intersection',
    'B1': 'Yield',
    'B19': 'Oncoming traffic has priority',
    'B5': 'Stop',
    'C1': 'No entry',
    'C11': 'No bikes',
    'C21': 'Maximum weight 5.5T',
    'C23': 'No delivery cars',
    'C27': 'Road max width 2.5m',
    'C29': 'Max height 3.5m',
    'C3': 'Passage restriction',
    'C31LEFT': 'No turn left',
    'C31RIGHT': 'No turn right',
    'C35': 'No overtaking',
    'C43': 'Speed limit 50',
    'D10': 'Bikes and pedestrians only',
    'D1a': 'Straight only',
    'D1b': 'Left only',
    'D3b': 'Straight or turn left',
    'D5': 'Roundabout',
    'D7': 'Bike path',
    'D9': 'Bike path and pedestrians separated',
    'E1': 'No parking',
    'E3': 'No stopping',
    'E5': 'No stopping between 1 and 15',
    'E7': 'No stopping between 16 and 31',
    'B21': 'Priority at this bottleneck',
    'E9a': 'Parking',
    'E9a_miva': 'Parking disability',
    'E9b': 'Parking cars only',
    'E9c': 'Parking trucks only',
    'E9d': 'Parking bus only',
    'E9e': 'Parking on sidewalk',
    'F12a': 'Play street',
    'F12b': 'End of play street',
    'F19': 'One way street',
    'F45': 'Dead end',
    'F47': 'End of construction works',
    'F49': 'Crosswalk',
    'F50': 'Bike path crossing',
    'F59': 'Parking on right',
    'F87': 'Speed bump',
    'B11': 'End of priority road',
    'B9': 'Priority road',
}

# %% [markdown]
# Reduce signs and merge

# %%
import os
import random
from shutil import copyfile
from PIL import Image
classes = []
reducedTS = ['A13','A14','A15','A1A','A1B','A1C','A1D','A23','A25','A29','A31','A33','A41','A51','A7A','A7B','A7C','B15A','B17','B1','B19','B5','C1','C11','C21','C23','C27','C29','C3','C31LEFT','C31RIGHT','C35','C43','D10','D1a','D1b','D3b','D5','D7','D9','E1','E3','E5','E7','B21','E9a','E9a_miva','E9b','E9c','E9d','E9e','F12a','F12b','F19','F45','F47','F49','F50','F59','F87','B11','B9',]
def convert_to_yolo_format(annotation, image_width, image_height):
    # Split the annotation string by semicolon
    parts = annotation.split(';')
    yolo_format=""
    # Extract the required values
    x1, y1, x2, y2 = map(float, parts[1:5])
    class_id = parts[11]
    print(class_id in reducedTS)
    if class_id in reducedTS:

        if class_names[class_id] not in classes:
            classes.append(class_names[class_id])
        class_id = classes.index(class_names[class_id])
        print(len(classes))
        # Calculate the YOLO format values
        x_center = (x1 + x2) / 2 / image_width
        y_center = (y1 + y2) / 2 / image_height
        width = (x2 - x1) / image_width
        height = (y2 - y1) / image_height
        assert(class_id < 64)
        # Create the YOLO format string
        yolo_format = f"{class_id} {x_center} {y_center} {width} {height}"
    
    return yolo_format

def transform_and_filter_lines(input_file, output_dir, target_directory):
    os.makedirs(output_dir, exist_ok=True)
    
    with open(input_file, 'r') as infile:
        for line in infile:
            parts = line[2:].split(';')
            image_path = parts[0][:-4] + '.jpg'
            image_file = os.path.join(target_directory, os.path.basename(image_path))
            #print(image_file)
            if os.path.exists(image_file):
                if True:
                    # Replace '01' with '00' at the start of the line
                    transformed_line = '00' + line[2:]
                    
                    # Get image dimensions
                    with Image.open(image_file) as img:
                        image_width, image_height = img.size
                    
                    # Convert to YOLO format
                    yolo_format = convert_to_yolo_format(transformed_line, image_width, image_height)
                    print(yolo_format)
                    # Write to YOLO format file
                    yolo_filename = os.path.splitext(os.path.basename(image_path))[0] + '.txt'
                    with open(os.path.join(output_dir, yolo_filename), 'w') as outfile:
                        outfile.write(yolo_format + '\n')
            else:
                continue
                #print(f"File not found: {image_file}")

def generate_yaml_file(output_dir, yaml_filename, c):
    yaml_content = f"""
train: {output_dir}/train/images
val: {output_dir}/val/images
test: {output_dir}/test/images

nc: {len(c)}  # number of classes
names: {c}  # class names
"""
    with open(yaml_filename, 'w') as yaml_file:
        yaml_file.write(yaml_content)

def split_dataset(dataset_dirs, output_dir):
    os.makedirs(os.path.join(output_dir, 'train/images'), exist_ok=True)
    os.makedirs(os.path.join(output_dir, 'train/labels'), exist_ok=True)
    os.makedirs(os.path.join(output_dir, 'val/images'), exist_ok=True)
    os.makedirs(os.path.join(output_dir, 'val/labels'), exist_ok=True)
    os.makedirs(os.path.join(output_dir, 'test/images'), exist_ok=True)
    os.makedirs(os.path.join(output_dir, 'test/labels'), exist_ok=True)
    
    images = []
    
    for dataset_dir in dataset_dirs:
        images.extend([os.path.join(dataset_dir, f) for f in os.listdir(dataset_dir) if f.endswith('.jpg') or f.endswith('.jp2')])
    
    random.shuffle(images)
    print(images)
    train_split = int(0.7 * len(images))
    val_split = int(0.85 * len(images))
    
    train_images = images[:train_split]
    val_images = images[train_split:val_split]
    test_images = images[val_split:]
    
    for img in train_images:
        try:
            copyfile(img, os.path.join(output_dir, 'train/images', os.path.basename(img)))
            copyfile(img.replace('.jpg', '.txt'), os.path.join(output_dir, 'train/labels', os.path.basename(img).replace('.jpg', '.txt')))
        except FileNotFoundError as e:
            print(f"FileNotFoundError: {e}")
        except PermissionError as e:
            print(f"PermissionError: {e}")
    
    for img in val_images:
        try:
            copyfile(img, os.path.join(output_dir, 'val/images', os.path.basename(img)))
            copyfile(img.replace('.jpg', '.txt'), os.path.join(output_dir, 'val/labels', os.path.basename(img).replace('.jpg', '.txt')))
        except FileNotFoundError as e:
            print(f"FileNotFoundError: {e}")
        except PermissionError as e:
            print(f"PermissionError: {e}")
    
    for img in test_images:
        try:
            copyfile(img, os.path.join(output_dir, 'test/images', os.path.basename(img)))
            copyfile(img.replace('.jpg', '.txt'), os.path.join(output_dir, 'test/labels', os.path.basename(img).replace('.jpg', '.txt')))
        except FileNotFoundError as e:
            print(f"FileNotFoundError: {e}")
        except PermissionError as e:
            print(f"PermissionError: {e}")

# Define the input and output file names and directories for BelgianTS dataset
belgian_input_file = 'annotations/training_GT_test.txt'
belgian_output_dir = 'yolo_belgian_annotations'
belgian_target_directory = 'camera00'

# Transform and filter the lines in the BelgianTS input file and save to the output directory
transform_and_filter_lines(belgian_input_file, belgian_output_dir, belgian_target_directory)

# Define the directories for DTLD dataset locations
dtld_locations = ['Bochum']

# Combine both datasets into a single directory list
combined_dataset_dirs = [belgian_target_directory]

for location in dtld_locations:
    dtld_images_dir = os.path.normpath(f'{location}/images/{location}')
    #dtld_labels_dir = os.path.normpath(f'{location}/labels/{location}')
    
    combined_dataset_dirs.append(dtld_images_dir)
    #combined_dataset_dirs.append(dtld_labels_dir)

classes.append("Red traffic light")
classes.append("Yellow traffic light")
classes.append("Green traffic light")
# Split the combined dataset into train, validation and test sets
split_dataset(combined_dataset_dirs, 'combined_yolo_annotations')

# Generate the YAML file for the combined dataset
generate_yaml_file('combined_yolo_annotations', 'data.yaml', classes)

print(f"YOLO format annotations have been saved to combined_yolo_annotations.")
print(f"YAML file has been generated as data.yaml.")
# Out:
# True
# 1
# 0 0.8995515970515969 0.2957807443365696 0.1445331695331695 0.19227346278317156
# True
# 1
# 0 0.7644871007371008 0.25699433656957926 0.09791769041769033 0.12897249190938515
# True
# 1
# 0 0.6984613022113022 0.23648462783171523 0.07347051597051604 0.09677184466019419
# True
# 2
# 1 0.9502119164619164 0.40934870550161817 0.03828624078624074 0.048406148867313904
# True
# 2
# 1 0.6681633906633907 0.32855987055016184 0.026461916461916417 0.03718446601941746
# True
# 2
# 1 0.7798863636363638 0.3635922330097087 0.0301167076167076 0.042135922330097074
# False
#
# False
#
# False
#
# True
# 3
# 2 0.6547051597051597 0.2108616504854369 0.01878378378378388 0.02406957928802589
# True
# 3
# 2 0.9613298525798526 0.25439724919093853 0.049993857493857555 0.0645064724919094
# True
# 3
# 2 0.730193488943489 0.219457928802589 0.026775184275184227 0.03202265372168286
# True
# 4
# 3 0.9402671990171991 0.25797734627831714 0.05490786240786247 0.06703883495145632
# True
# 4
# 3 0.8632340294840295 0.24309870550161813 0.03886363636363635 0.047880258899676384
# True
# 4
# 3 0.833931203931204 0.22750809061488678 0.03192874692874694 0.03818770226537216
# True
# 4
# 0 0.9416461916461917 0.2814401294498382 0.11482800982800986 0.14893203883495143
# True
# 4
# 0 0.8481511056511056 0.25818365695792883 0.08942260442260438 0.11722491909385115
# True
# 4
# 0 0.7654699017199017 0.24248381877022657 0.06665233415233415 0.08915857605177993
# True
# 5
# 4 0.9370423832923833 0.22389967637540453 0.04907248157248163 0.061423948220064715
# True
# 5
# 4 0.8669072481572482 0.22205097087378645 0.03636977886977889 0.047677993527508095
# False
#
# False
#
# True
# 5
# 2 0.7897113022113023 0.38792071197411 0.06576167076167087 0.0789967637540453
# True
# 5
# 2 0.9056941031941033 0.48048948220064724 0.0903316953316953 0.1070792880258899
# True
# 6
# 5 0.7135227272727273 0.21732200647249192 0.03114864864864867 0.03781553398058253
# True
# 6
# 5 0.824551597051597 0.23252831715210354 0.04538083538083531 0.05449029126213592
# True
# 6
# 5 0.9310012285012286 0.2428276699029126 0.05996314496314504 0.07182038834951456
# False
#
# False
#
# True
# 7
# 6 0.910546683046683 0.2936407766990291 0.06058968058968065 0.07925566343042074
# True
# 7
# 6 0.8011087223587223 0.25431634304207124 0.040386977886977884 0.052322006472491925
# False
#
# False
#
# True
# 8
# 7 0.8098218673218672 0.23789644012944985 0.0541154791154792 0.0718284789644013
# True
# 8
# 7 0.5639342751842752 0.21831310679611654 0.03582923832923835 0.048778317152103574
# True
# 9
# 8 0.741965601965602 0.16065129449838186 0.04089680589680585 0.08457119741100323
# True
# 9
# 8 0.5663083538083539 0.16960355987055015 0.032542997542997554 0.06715210355987054
# True
# 9
# 8 0.9418550368550369 0.16143203883495144 0.062088452088452185 0.11822006472491907
# False
#
# False
#
# True
# 9
# 8 0.9707923832923832 0.14224514563106797 0.05660933660933666 0.09557443365695792
# True
# 9
# 8 0.920666461916462 0.1592192556634304 0.04593980343980342 0.07746763754045308
# True
# 9
# 8 0.8965018427518429 0.16676779935275082 0.03549754299754312 0.06463592233009707
# False
#
# False
#
# False
#
# True
# 9
# 8 0.9571130221130222 0.134789644012945 0.05891891891891896 0.1076051779935275
# True
# 9
# 8 0.8502886977886978 0.15203478964401293 0.04262899262899268 0.0813673139158576
# True
# 9
# 8 0.7844563882063882 0.16499190938511327 0.03445331695331704 0.06807443365695792
# False
#
# False
#
# False
#
# True
# 9
# 7 0.8758323095823096 0.1995388349514563 0.109563882063882 0.14629449838187705
# True
# 9
# 7 0.6881633906633906 0.19211165048543688 0.05721130221130227 0.07694174757281554
# True
# 9
# 7 0.5967536855036855 0.20403721682847897 0.03358108108108113 0.04538834951456312
# True
# 10
# 9 0.9576873464373464 0.11148867313915856 0.07098894348894359 0.13166666666666665
# True
# 10
# 9 0.7966308353808353 0.13142394822006473 0.042622850122850046 0.08723300970873786
# True
# 10
# 9 0.7148003685503685 0.1613794498381877 0.03149262899262898 0.06486245954692559
# False
#
# False
#
# False
#
# True
# 10
# 9 0.9481664619164619 0.13496359223300972 0.0581633906633907 0.10665857605177992
# True
# 10
# 9 0.8365970515970516 0.14661812297734628 0.040614250614250544 0.08090614886731391
# True
# 10
# 9 0.768617936117936 0.1543851132686084 0.03158476658476663 0.06411003236245956
# False
#
# False
#
# False
#
# True
# 10
# 7 0.9790018427518428 0.21103155339805824 0.04011670761670758 0.057127831715210346
# True
# 10
# 7 0.8563359950859951 0.19946197411003236 0.03318796068796081 0.04434466019417476
# True
# 10
# 7 0.7741369778869779 0.19369741100323626 0.02703316953316953 0.03671521035598707
# True
# 10
# 7 0.9817690417690418 0.11521440129449838 0.034459459459459406 0.04722491909385114
# True
# 10
# 7 0.8895792383292384 0.13156148867313916 0.028249385749385757 0.037783171521035615
# True
# 11
# 10 0.971858108108108 0.20378640776699028 0.05541154791154793 0.07100323624595468
# True
# 11
# 10 0.8863267813267813 0.20254045307443366 0.0473710073710073 0.05533980582524275
# False
#
# False
#
# False
#
# True
# 11
# 7 0.8453746928746929 0.04939724919093851 0.07624078624078617 0.09879449838187702
# True
# 11
# 7 0.7327825552825553 0.09175161812297734 0.05154791154791159 0.06911812297734628
# True
# 11
# 7 0.6613943488943489 0.12425161812297733 0.03625307125307124 0.04821197411003236
# True
# 12
# 11 0.8417628992628992 0.20124595469255663 0.14538083538083543 0.191084142394822
# True
# 12
# 11 0.7321222358722359 0.19555016181229776 0.09847051597051594 0.1284789644012945
# True
# 12
# 11 0.6621068796068795 0.19722491909385112 0.06803439803439802 0.09101941747572813
# True
# 13
# 12 0.7066615479115479 0.0383373786407767 0.05457616707616702 0.06596278317152103
# True
# 13
# 12 0.6707309582309583 0.06651699029126214 0.045491400491400456 0.05382686084142395
# True
# 13
# 12 0.646286855036855 0.08146035598705502 0.03837223587223596 0.046626213592233005
# False
#
# False
#
# False
#
# True
# 13
# 9 0.9563636363636364 0.18757686084142391 0.029152334152334175 0.05622168284789642
# False
#
# False
#
# False
#
# False
#
# True
# 13
# 9 0.8996560196560196 0.16540857605177994 0.08590909090909085 0.1629854368932039
# True
# 13
# 9 0.774103194103194 0.17561488673139158 0.06035626535626535 0.11699029126213593
# True
# 13
# 9 0.6828839066339067 0.17954692556634305 0.04249999999999989 0.08608414239482201
# False
#
# False
#
# False
#
# True
# 13
# 7 0.8631449631449631 0.07940938511326862 0.06078624078624081 0.08485436893203883
# True
# 13
# 7 0.7684520884520885 0.10950242718446603 0.044815724815724836 0.06232200647249192
# True
# 13
# 7 0.7165110565110565 0.12533576051779938 0.034889434889435 0.04745145631067962
# True
# 13
# 11 0.7615816953316954 0.20266181229773464 0.08517813267813272 0.11477346278317153
# True
# 13
# 11 0.8505313267813268 0.2096561488673139 0.12092751842751837 0.1581472491909385
# True
# 13
# 11 0.7112039312039313 0.19860436893203887 0.06617936117936118 0.09083333333333334
# True
# 14
# 13 0.9494195331695332 0.21819983818770225 0.0797235872235872 0.09510517799352754
# True
# 14
# 13 0.8221590909090909 0.21089401294498378 0.05490786240786247 0.0700242718446602
# True
# 14
# 7 0.5429299754299755 0.04221682847896441 0.04160933660933661 0.05762135922330097
# True
# 14
# 12 0.535328624078624 0.11973705501618123 0.07089066339066344 0.09007281553398058
# True
# 14
# 11 0.5324355036855036 0.21836569579288023 0.07892506142506144 0.10653721682847897
# True
# 15
# 14 0.9599508599508599 0.18492313915857606 0.041855036855036776 0.05350323624595469
# True
# 15
# 14 0.8530067567567569 0.18059061488673137 0.031676904176904136 0.04250809061488672
# False
#
# False
#
# True
# 15
# 14 0.7984674447174448 0.2216990291262136 0.0258169533169533 0.03533980582524272
# True
# 15
# 14 0.8534060196560197 0.23112055016181227 0.02899877149877152 0.04133495145631066
# True
# 15
# 14 0.9316584766584767 0.24210760517799354 0.03524570024570031 0.049555016181229775
# True
# 15
# 14 0.856517199017199 0.1942313915857605 0.02796068796068795 0.03660194174757282
# True
# 15
# 14 0.9334551597051597 0.20148867313915858 0.03406019656019659 0.0440453074433657
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# True
# 16
# 15 0.8804576167076167 0.20663430420711976 0.026173218673218753 0.03624595469255664
# True
# 16
# 15 0.9734705159705159 0.2144619741100324 0.033464373464373476 0.04525080906148868
# True
# 16
# 15 0.8074938574938575 0.20546521035598705 0.02216216216216226 0.030558252427184452
# False
#
# False
#
# True
# 16
# 15 0.86367628992629 0.21925970873786407 0.03778255528255528 0.04897249190938509
# True
# 16
# 15 0.9450644963144963 0.22838996763754046 0.045362407862407805 0.058964401294498404
# False
#
# False
#
# True
# 16
# 7 0.929358108108108 0.09067556634304207 0.06656633906633914 0.08767799352750809
# True
# 16
# 7 0.7740264127764128 0.13027508090614887 0.0364926289926289 0.0473948220064725
# True
# 16
# 7 0.7015386977886978 0.16627427184466018 0.024772727272727228 0.03311488673139157
# True
# 16
# 11 0.9207463144963144 0.21620954692556635 0.11874078624078635 0.1563996763754045
# True
# 16
# 11 0.7710718673218672 0.19848300970873786 0.06605036855036853 0.08699838187702263
# True
# 16
# 11 0.6997819410319409 0.21268608414239482 0.04420761670761673 0.05888349514563104
# True
# 17
# 16 0.9204821867321867 0.22715210355987053 0.05007985257985256 0.057508090614886744
# True
# 17
# 16 0.9492383292383292 0.23209546925566343 0.06142506142506143 0.06906148867313917
# True
# 17
# 16 0.9095945945945946 0.2204935275080906 0.03226044226044225 0.03637540453074432
# True
# 17
# 16 0.9577825552825553 0.22457928802589 0.03509828009828002 0.03898058252427185
# True
# 17
# 16 0.8702641277641278 0.2203195792880259 0.028955773955773877 0.03351941747572814
# False
#
# False
#
# False
#
# True
# 17
# 7 0.8733906633906635 0.09085760517799353 0.06993857493857487 0.09016181229773464
# True
# 17
# 7 0.8045945945945947 0.11338592233009707 0.049864864864864904 0.06512135922330095
# True
# 17
# 7 0.7643581081081081 0.1323098705501618 0.04009213759213758 0.05314724919093851
# True
# 17
# 11 0.9096560196560197 0.21048948220064725 0.12914004914004915 0.164247572815534
# True
# 17
# 11 0.8324815724815725 0.2033616504854369 0.0946560196560196 0.12353559870550161
# True
# 17
# 11 0.7876351351351352 0.20342637540453073 0.07479115479115478 0.0978398058252427
# True
# 18
# 17 0.0601044226044226 0.11253236245954693 0.05628992628992628 0.08880258899676376
# True
# 18
# 17 0.2873280098280098 0.09368527508090614 0.03382063882063882 0.0631472491909385
# True
# 19
# 18 0.9529944717444717 0.17156148867313917 0.04285626535626535 0.07385113268608415
# True
# 19
# 18 0.888058968058968 0.17657766990291263 0.03487714987715 0.062200647249190937
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# True
# 19
# 15 0.8721375921375921 0.16759708737864076 0.03932432432432431 0.08970873786407764
# True
# 19
# 15 0.541698402948403 0.17535598705501618 0.03143120393120397 0.06233009708737863
# True
# 19
# 15 0.32241093366093365 0.1628398058252427 0.025730958230958258 0.04779935275080907
# True
# 19
# 17 0.9135135135135135 0.18626618122977348 0.0260319410319411 0.046626213592233026
# True
# 19
# 17 0.9698095823095823 0.1845064724919094 0.030638820638820567 0.05367313915857608
# False
#
# False
#
# False
#
# True
# 19
# 15 0.9575092137592136 0.1754935275080906 0.05778255528255524 0.07893203883495145
# True
# 19
# 15 0.8357708845208845 0.17470873786407767 0.040350122850122884 0.05449838187702266
# True
# 19
# 15 0.7564097051597052 0.1783009708737864 0.03160319410319413 0.04257281553398059
# False
#
# False
#
# False
#
# True
# 19
# 7 0.900218058968059 0.17430825242718445 0.13247542997543002 0.1744902912621359
# True
# 19
# 7 0.8180128992628992 0.1778074433656958 0.09817567567567577 0.1310032362459547
# True
# 19
# 7 0.7583875921375921 0.17577265372168285 0.07299140049140045 0.09580097087378638
# True
# 19
# 18 0.9646191646191646 0.11001618122977345 0.04968058968058961 0.09359223300970873
# True
# 19
# 18 0.9150429975429976 0.12296116504854368 0.03986486486486492 0.0809061488673139
# True
# 19
# 18 0.8607401719901719 0.1338551779935275 0.030423832923832907 0.06678802588996764
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# True
# 19
# 8 0.9659428746928745 0.10733818770226539 0.04847051597051602 0.082831715210356
# True
# 19
# 8 0.8973249385749384 0.11633899676375403 0.03531326781326782 0.06466828478964401
# True
# 19
# 8 0.8600522113022113 0.13193770226537216 0.029121621621621532 0.0557200647249191
# False
#
# False
#
# False
#
# True
# 19
# 12 0.8824785012285014 0.3547168284789644 0.09125921375921373 0.10203883495145631
# True
# 19
# 12 0.8151074938574938 0.3191747572815534 0.07270884520884528 0.08228155339805829
# True
# 19
# 12 0.7713359950859952 0.2970105177993528 0.061947174447174534 0.0664644012944984
# True
# 19
# 3 0.7694502457002457 0.3681553398058252 0.05968673218673223 0.06944983818770224
# True
# 19
# 3 0.8111394348894349 0.40466019417475724 0.07124692874692876 0.0825566343042071
# True
# 19
# 3 0.8758323095823096 0.46114886731391586 0.08749999999999988 0.1000647249190939
# True
# 19
# 16 0.7357125307125307 0.2140655339805825 0.0513513513513513 0.060542071197411014
# True
# 19
# 16 0.9170393120393121 0.23914644012944983 0.09250614250614245 0.10347087378640775
# True
# 19
# 16 0.6508077395577395 0.2029490291262136 0.03378992628992628 0.04083333333333331
# True
# 20
# 19 0.898458230958231 0.2590655339805825 0.05898034398034397 0.12764563106796115
# True
# 20
# 19 0.4870761670761671 0.23976941747572816 0.035184275184275166 0.07772653721682847
# True
# 20
# 19 0.11055896805896806 0.255918284789644 0.03078624078624079 0.059603559870550125
# True
# 20
# 5 0.6645147420147419 0.24419902912621363 0.04240786240786239 0.053365695792880245
# True
# 20
# 5 0.8686701474201475 0.337742718446602 0.08931818181818187 0.11949838187702265
# True
# 20
# 5 0.6132125307125307 0.23537621359223299 0.026547911547911494 0.0328074433656958
# True
# 21
# 20 0.8915110565110566 0.3287014563106796 0.12878378378378383 0.1623705501618123
# True
# 21
# 20 0.5792291154791155 0.22166262135922332 0.02738943488943484 0.037160194174757286
# True
# 21
# 20 0.6666185503685504 0.24642799352750813 0.05291769041769034 0.07062297734627833
# True
# 22
# 21 0.8439864864864864 0.2760962783171521 0.08244471744471732 0.1034870550161812
# True
# 22
# 21 0.609066339066339 0.23133899676375405 0.037899262899262855 0.0448624595469256
# True
# 22
# 21 0.5196130221130222 0.21531148867313915 0.024250614250614193 0.029619741100323636
# True
# 22
# 2 0.8403624078624078 0.5293082524271845 0.09244471744471744 0.11101132686084145
# True
# 22
# 2 0.6303562653562653 0.3370631067961165 0.03963144963144962 0.04911003236245954
# True
# 22
# 2 0.5603562653562654 0.28483009708737866 0.023058968058968038 0.0299190938511327
# True
# 23
# 22 0.8764465601965602 0.2783252427184466 0.12134520884520895 0.15506472491909382
# True
# 23
# 22 0.7626074938574939 0.2533454692556634 0.08335995085995088 0.10732200647249189
# True
# 23
# 22 0.7009305896805896 0.24003236245954693 0.06351965601965592 0.0833818770226537
# True
# 24
# 23 0.8872113022113023 0.6114603559870551 0.12637592137592138 0.13974919093851135
# True
# 24
# 23 0.6377395577395577 0.33024271844660197 0.043022113022113 0.052896440129449836
# True
# 24
# 23 0.5853071253071253 0.2787742718446602 0.02527027027027033 0.03196601941747572
# False
#
# False
#
# False
#
# True
# 24
# 16 0.9306326781326782 0.265586569579288 0.09355036855036852 0.10740291262135922
# True
# 24
# 16 0.6925092137592137 0.22372168284789642 0.04477272727272719 0.052750809061488685
# True
# 24
# 16 0.5745485257985258 0.21308252427184465 0.029379606879606834 0.03509708737864077
# True
# 25
# 24 0.9308230958230959 0.2541059870550162 0.0802334152334153 0.10452265372168287
# True
# 25
# 24 0.6423802211302212 0.2099433656957929 0.030509828009828054 0.03980582524271844
# True
# 25
# 24 0.6930712530712531 0.22522653721682848 0.03986486486486492 0.048770226537216806
# False
#
# False
#
# False
#
# True
# 25
# 3 0.9380436117936118 0.39137135922330096 0.05759828009828009 0.06390776699029127
# True
# 25
# 3 0.7701382063882063 0.3062580906148867 0.031406633906633834 0.037467637540453076
# True
# 25
# 3 0.7111824324324323 0.2791585760517799 0.023040540540540534 0.029708737864077645
# False
#
# False
#
# False
#
# True
# 25
# 3 0.6758998771498772 0.1768406148867314 0.027364864864864977 0.037208737864077655
# True
# 25
# 3 0.9480651105651104 0.12872168284789642 0.06713759213759211 0.08923948220064724
# True
# 25
# 3 0.6268673218673219 0.18444174757281553 0.018513513513513435 0.024563106796116514
# False
#
# False
#
# False
#
# True
# 26
# 25 0.8610288697788698 0.3076415857605178 0.051652334152334105 0.10005663430420708
# True
# 26
# 25 0.9433906633906635 0.34063106796116505 0.06624078624078619 0.12135922330097088
# True
# 26
# 25 0.7423341523341523 0.2700040453074434 0.03535626535626532 0.07025080906148866
# True
# 26
# 19 0.9674447174447175 0.20979773462783172 0.049226044226044145 0.08016181229773464
# True
# 26
# 19 0.9317260442260442 0.21848300970873782 0.035466830466830475 0.06165857605177992
# True
# 26
# 19 0.9403808353808354 0.22083333333333333 0.02864864864864871 0.0504368932038835
# False
#
# False
#
# True
# 26
# 16 0.9283384520884521 0.22798948220064727 0.1052027027027027 0.11670711974110035
# True
# 26
# 16 0.7849170761670761 0.20597896440129448 0.054957002457002475 0.06432038834951453
# True
# 26
# 16 0.7161762899262899 0.19717233009708737 0.032291154791154755 0.03759708737864077
# False
#
# False
#
# False
#
# True
# 27
# 26 0.860267199017199 0.12826860841423948 0.08735257985257973 0.1134304207119741
# True
# 27
# 26 0.8961578624078623 0.11668284789644012 0.09877764127764124 0.12603559870550166
# True
# 27
# 26 0.7625644963144963 0.16432443365695792 0.06463759213759215 0.08560679611650486
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# True
# 27
# 0 0.9303439803439802 0.337212783171521 0.10874692874692872 0.13382686084142398
# True
# 27
# 0 0.8456910319410319 0.3135153721682848 0.08241400491400482 0.10570388349514562
# True
# 27
# 0 0.755933660933661 0.3035639158576052 0.06142506142506143 0.07973300970873787
# True
# 27
# 21 0.6595976658476659 0.2799959546925566 0.06629606879606877 0.08961974110032361
# True
# 27
# 21 0.5041769041769042 0.27316343042071195 0.05237100737100737 0.06755663430420712
# False
#
# False
#
# True
# 27
# 22 0.9111486486486486 0.22102346278317153 0.13366093366093373 0.1760598705501618
# True
# 27
# 22 0.7960503685503686 0.24022249190938513 0.09002457002457 0.12016990291262136
# True
# 27
# 22 0.7380251842751844 0.24073624595469256 0.0693673218673219 0.09163430420711975
# True
# 28
# 27 0.902985257985258 0.09090210355987055 0.1181572481572481 0.14848705501618123
# True
# 28
# 27 0.6596314496314497 0.11112459546925565 0.07877149877149878 0.1061326860841424
# True
# 28
# 27 0.42654176904176905 0.13801779935275083 0.06431203931203934 0.08470873786407768
# False
#
# False
#
# False
#
# True
# 28
# 20 0.9061271498771498 0.20935679611650485 0.11200859950859945 0.14419902912621357
# True
# 28
# 20 0.7010872235872235 0.1985517799352751 0.05737100737100729 0.07689320388349516
# True
# 28
# 20 0.7965049140049141 0.20597491909385113 0.0816584766584767 0.1104126213592233
# True
# 28
# 22 0.902159090909091 0.23853155339805823 0.08665233415233412 0.11207928802588994
# True
# 28
# 22 0.761842751842752 0.20854773462783172 0.06038083538083535 0.08021844660194173
# True
# 28
# 22 0.6809613022113022 0.20350728155339803 0.04593980343980342 0.0618851132686084
# True
# 28
# 21 0.9018519656019657 0.3338915857605178 0.10554668304668315 0.13218446601941747
# True
# 28
# 21 0.7997297297297298 0.29271035598705497 0.07823095823095831 0.09750809061488676
# True
# 28
# 21 0.734222972972973 0.26607605177993526 0.060988943488943466 0.07632686084142397
# False
#
# False
#
# False
#
# True
# 28
# 9 0.8671253071253071 0.18977346278317153 0.05411547911547906 0.10291262135922331
# True
# 28
# 9 0.9548003685503685 0.18954692556634303 0.07151719901719905 0.12972491909385112
# True
# 28
# 9 0.7588667076167076 0.1839522653721683 0.03636977886977889 0.07173948220064724
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# True
# 28
# 2 0.9222604422604423 0.2820833333333333 0.06038083538083535 0.07449029126213591
# True
# 28
# 2 0.8343273955773954 0.267455501618123 0.04983415233415226 0.0620145631067961
# True
# 28
# 2 0.7692782555282556 0.25574029126213593 0.04215601965601972 0.05075242718446599
# True
# 28
# 21 0.9340847665847666 0.33176375404530745 0.059508599508599574 0.07220064724919095
# True
# 28
# 21 0.8487929975429975 0.31961569579288024 0.04845823095823088 0.05800161812297734
# False
#
# False
#
# True
# 28
# 21 0.9164373464373464 0.40565533980582524 0.09326781326781336 0.11095469255663434
# True
# 28
# 21 0.8192045454545455 0.3550404530744337 0.0716891891891892 0.08640776699029128
# True
# 28
# 21 0.7586179361179362 0.3234385113268608 0.057444717444717436 0.06851132686084142
# False
#
# False
#
# False
#
# True
# 28
# 21 0.9084766584766585 0.3119741100323625 0.0903316953316953 0.1066828478964401
# False
#
# True
# 29
# 28 0.9557432432432431 0.2115210355987055 0.08185503685503685 0.09922330097087377
# True
# 29
# 28 0.8431449631449632 0.20426779935275083 0.06079852579852581 0.07292071197411006
# True
# 29
# 28 0.7756203931203931 0.20236650485436894 0.04895577395577398 0.05866504854368931
# True
# 29
# 7 0.9026965601965603 0.2331027508090615 0.08527027027027023 0.11279126213592233
# True
# 29
# 7 0.4107340294840295 0.21190938511326857 0.03883906633906635 0.05234627831715209
# True
# 29
# 7 0.18319717444717445 0.23267799352750812 0.031136363636363636 0.03949838187702265
# True
# 30
# 29 0.9054054054054054 0.39705906148867315 0.17740786240786252 0.21605987055016176
# True
# 30
# 29 0.4229299754299754 0.29083333333333333 0.08611793611793614 0.10708737864077666
# True
# 30
# 29 0.19424754299754302 0.29314320388349513 0.06507985257985258 0.08159385113268611
# False
#
# False
#
# False
#
# True
# 31
# 30 0.9195792383292384 0.22023462783171519 0.09605036855036848 0.1299514563106796
# True
# 31
# 30 0.8249140049140049 0.21136326860841426 0.07433660933660932 0.10109223300970875
# True
# 31
# 30 0.765386977886978 0.20841423948220067 0.061547911547911574 0.08360841423948218
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# True
# 31
# 28 0.8213175675675676 0.13635113268608415 0.07646805896805897 0.09775080906148867
# True
# 31
# 28 0.9089281326781328 0.12433252427184467 0.09785626535626546 0.12730582524271844
# True
# 31
# 28 0.7511762899262899 0.14741100323624595 0.060460687960688 0.07550161812297736
# False
#
# False
#
# False
#
# True
# 31
# 24 0.9310595823095822 0.3347208737864078 0.12646805896805902 0.14555825242718448
# True
# 31
# 24 0.6994717444717444 0.25491100323624594 0.05603194103194091 0.06784789644012947
# True
# 31
# 24 0.8419379606879607 0.5965938511326861 0.1786547911547911 0.21024271844660194
# True
# 31
# 24 0.6940233415233414 0.42002831715210354 0.10251842751842744 0.1230663430420712
# True
# 31
# 24 0.6340694103194102 0.3467313915857605 0.07098894348894345 0.08491909385113272
# True
# 31
# 7 0.8302856265356265 0.3440210355987055 0.08867936117936125 0.11907766990291263
# True
# 31
# 7 0.6674907862407864 0.27165453074433654 0.04887592137592134 0.06609223300970873
# True
# 31
# 7 0.5991369778869778 0.24789239482200645 0.03360565110565113 0.04617313915857604
# False
#
# False
#
# False
#
# True
# 31
# 23 0.9205804668304668 0.29758899676375405 0.10659090909090907 0.12611650485436893
# True
# 31
# 23 0.7948065110565111 0.27103155339805823 0.07151719901719905 0.0891504854368932
# True
# 31
# 23 0.7466308353808353 0.2579004854368932 0.06090294840294832 0.07241909385113268
# True
# 31
# 25 0.8884582309582308 0.11052588996763756 0.07144963144963141 0.15470873786407766
# True
# 31
# 25 0.79262285012285 0.1298705501618123 0.05767813267813259 0.11689320388349514
# True
# 31
# 25 0.6902364864864864 0.14675161812297735 0.04015356265356273 0.07992718446601942
# False
#
# False
#
# False
#
# True
# 31
# 21 0.9429207616707616 0.3347087378640777 0.11328624078624082 0.1459546925566343
# True
# 31
# 21 0.8044441031941032 0.2882200647249191 0.07838452088452097 0.097831715210356
# True
# 31
# 21 0.7332862407862407 0.26319983818770226 0.05992628992628989 0.07385922330097085
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# True
# 31
# 27 0.7786547911547912 0.20345873786407767 0.054742014742014816 0.15944174757281554
# True
# 31
# 27 0.5170515970515971 0.23961569579288022 0.041523341523341466 0.10656148867313914
# True
# 31
# 27 0.3995270270270271 0.26617313915857604 0.03509828009828009 0.086537216828479
# True
# 31
# 26 0.7411455773955774 0.19761326860841424 0.07299140049140045 0.09749190938511326
# True
# 31
# 26 0.9177641277641277 0.20080501618122976 0.14692874692874697 0.20246763754045308
# True
# 31
# 26 0.7965110565110564 0.19902508090614887 0.09785012285012282 0.13172330097087376
# False
#
# False
#
# False
#
# True
# 32
# 31 0.9084674447174448 0.23033576051779936 0.0860380835380835 0.1093770226537217
# True
# 32
# 31 0.8129699017199017 0.22088592233009707 0.06660319410319414 0.08513754045307442
# True
# 32
# 31 0.7129545454545455 0.20611650485436894 0.04773955773955776 0.06092233009708739
# True
# 32
# 12 0.8840663390663392 0.2112864077669903 0.03762899262899262 0.04603559870550165
# True
# 32
# 12 0.9485472972972974 0.221415857605178 0.042598280098280185 0.05088996763754046
# True
# 32
# 28 0.9437592137592138 0.2716504854368932 0.0412407862407863 0.04893203883495147
# True
# 32
# 28 0.8802242014742016 0.25620550161812294 0.03688574938574936 0.04250809061488675
# True
# 32
# 3 0.931941031941032 0.21682038834951456 0.03571253071253063 0.040453074433656956
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# True
# 32
# 11 0.9684981572481572 0.23144417475728155 0.04408476658476657 0.055315533980582525
# False
#
# False
#
# True
# 33
# 32 0.9391431203931203 0.3006512944983819 0.037610565110565125 0.06164239482200647
# True
# 33
# 32 0.8867137592137592 0.28560679611650486 0.032235872235872244 0.05307443365695795
# True
# 34
# 33 0.9041400491400492 0.3555582524271845 0.10767813267813266 0.13516181229773463
# True
# 34
# 33 0.7399385749385748 0.30489886731391586 0.07808353808353816 0.09483009708737862
# True
# 34
# 33 0.5885350122850123 0.2605218446601942 0.053273955773955786 0.06411812297734627
# False
#
# False
#
# True
# 34
# 23 0.7185595823095824 0.3618163430420712 0.08649262899262895 0.1017071197411003
# True
# 34
# 23 0.7906848894348895 0.4183333333333334 0.11345823095823084 0.1337378640776699
# True
# 34
# 23 0.9217291154791155 0.5250687702265371 0.15564496314496307 0.19266181229773463
# True
# 34
# 23 0.1387100737100737 0.3250040453074434 0.06395577395577395 0.08376213592233012
# True
# 34
# 23 0.18764127764127767 0.29909789644012946 0.053832923832923825 0.0694902912621359
# True
# 34
# 23 0.061931818181818185 0.36298543689320384 0.08021498771498772 0.1061326860841424
# True
# 34
# 31 0.9454821867321866 0.3065008090614887 0.04958845208845196 0.06233818770226538
# True
# 34
# 31 0.8617045454545454 0.2845469255663431 0.04210687960687972 0.052022653721682854
# True
# 34
# 31 0.8208906633906633 0.27552588996763755 0.038206388206388234 0.0470064724919094
# True
# 34
# 25 0.9413052825552827 0.384336569579288 0.03532555282555282 0.06509708737864076
# True
# 34
# 25 0.8595300982800983 0.35032766990291264 0.028015970515970455 0.054781553398058284
# True
# 34
# 25 0.8186025798525798 0.334004854368932 0.024932432432432382 0.04925566343042071
# True
# 34
# 17 0.9670608108108109 0.12923948220064727 0.03845823095823104 0.07357605177993529
# True
# 34
# 17 0.8941584766584767 0.14078074433656956 0.029840294840294795 0.05704692556634303
# False
#
# False
#
# True
# 34
# 22 0.9209613022113022 0.21347087378640778 0.08581695331695334 0.10906148867313917
# True
# 34
# 22 0.8332678132678132 0.21049352750809058 0.06560196560196557 0.08480582524271844
# True
# 34
# 22 0.779247542997543 0.2041181229773463 0.053937346437346406 0.06990291262135923
# True
# 34
# 3 0.9667813267813268 0.09967637540453074 0.06342751842751843 0.08255663430420711
# True
# 34
# 3 0.8531326781326782 0.1201051779935275 0.04738329238329245 0.06009708737864078
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# True
# 35
# 34 0.9123126535626535 0.14904935275080905 0.058667076167076164 0.1301051779935275
# True
# 35
# 34 0.12563267813267814 0.20523462783171523 0.032592137592137596 0.06637540453074434
# True
# 35
# 34 0.5317874692874693 0.15884708737864076 0.038857493857493854 0.08916666666666667
# False
#
# False
#
# True
# 36
# 35 0.8991369778869779 0.22709951456310679 0.08675061425061426 0.1505906148867314
# True
# 36
# 35 0.6994471744471745 0.20125809061488673 0.04428746928746923 0.08599514563106793
# True
# 36
# 35 0.779477886977887 0.20873381877022654 0.05766584766584773 0.11034789644012943
# True
# 36
# 24 0.9131756756756757 0.21972896440129452 0.09466830466830474 0.11136731391585764
# True
# 36
# 24 0.820279484029484 0.21709546925566348 0.0714557739557739 0.08530744336569579
# True
# 36
# 24 0.7589219901719902 0.2074069579288026 0.05742628992628993 0.06921521035598704
# False
#
# False
#
# False
#
# True
# 37
# 36 0.9079115479115478 0.32517799352750804 0.10179361179361181 0.1377022653721683
# True
# 37
# 36 0.7948802211302212 0.29438511326860844 0.07646805896805897 0.10368932038834953
# True
# 37
# 36 0.7070546683046683 0.2600566343042071 0.05490786240786233 0.07496763754045305
# False
#
# False
#
# False
#
# True
# 38
# 37 0.9091984029484029 0.190752427184466 0.105558968058968 0.13284789644012945
# True
# 38
# 37 0.8208783783783783 0.1890776699029126 0.08465601965601961 0.10517799352750809
# True
# 38
# 37 0.7217475429975431 0.19440129449838187 0.061959459459459534 0.07432038834951456
# True
# 38
# 25 0.8154299754299754 0.29650485436893204 0.056081081081081195 0.11080906148867312
# True
# 38
# 25 0.9009244471744471 0.32760922330097086 0.07216830466830468 0.13860032362459548
# True
# 38
# 25 0.7186517199017198 0.2705946601941747 0.040350122850122884 0.07667475728155339
# False
#
# False
#
# False
#
# True
# 38
# 13 0.8864957002457003 0.1977224919093851 0.03713144963144966 0.04465210355987057
# True
# 38
# 13 0.9740233415233416 0.2002831715210356 0.04426289926289923 0.04933656957928804
# True
# 38
# 13 0.7816554054054053 0.19080097087378642 0.030411547911547907 0.03946601941747575
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# True
# 38
# 13 0.9601382063882064 0.24183252427184465 0.07262285012285014 0.08976537216828478
# True
# 38
# 13 0.7673986486486487 0.2222977346278317 0.040374692874692884 0.053754045307443384
# True
# 38
# 13 0.70122542997543 0.2086690938511327 0.030485257985258054 0.040347896440129476
# False
#
# False
#
# False
#
# True
# 38
# 20 0.8910841523341523 0.25830501618122975 0.14160319410319408 0.17842233009708736
# True
# 38
# 20 0.6296805896805896 0.19917880258899676 0.05723587223587227 0.07753236245954694
# True
# 38
# 20 0.474914004914005 0.20173948220064725 0.037567567567567545 0.04891585760517798
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# True
# 39
# 38 0.8298126535626535 0.2051982200647249 0.022426289926289922 0.03484627831715212
# True
# 39
# 38 0.9613390663390663 0.20820792880258898 0.03227272727272725 0.05246763754045307
# True
# 39
# 38 0.8544318181818181 0.2010234627831715 0.024944717444717383 0.039668284789644036
# True
# 39
# 0 0.9484367321867322 0.16650080906148867 0.07173832923832922 0.09183656957928804
# True
# 39
# 0 0.8010995085995086 0.1700687702265372 0.04792383292383291 0.06253236245954692
# True
# 39
# 0 0.7094441031941031 0.17794498381877022 0.036271498771498746 0.04734627831715209
# True
# 39
# 3 0.9653992628992629 0.15591423948220065 0.0645331695331695 0.08398058252427186
# True
# 39
# 3 0.7094840294840294 0.1793648867313916 0.03228501228501225 0.040558252427184464
# True
# 39
# 3 0.6423894348894349 0.17526699029126214 0.021891891891891953 0.026488673139158585
# True
# 39
# 29 0.9569195331695332 0.09947411003236245 0.07315110565110575 0.1046116504854369
# True
# 39
# 29 0.7573740786240787 0.1482807443365696 0.04188574938574928 0.05516990291262136
# True
# 39
# 29 0.6945700245700246 0.1651415857605178 0.0305773955773957 0.038616504854368926
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# True
# 39
# 2 0.956504914004914 0.44474919093851134 0.08111793611793608 0.10103559870550162
# True
# 39
# 2 0.7356357493857494 0.3236529126213592 0.04370393120393126 0.053211974110032395
# True
# 39
# 2 0.6602457002457003 0.27757686084142397 0.030270270270270253 0.03662621359223304
# True
# 39
# 36 0.8758015970515971 0.06188915857605178 0.07412162162162167 0.10128640776699029
# True
# 39
# 36 0.7492751842751842 0.09339401294498383 0.053144963144963135 0.07177184466019416
# True
# 39
# 36 0.6744993857493857 0.12013754045307444 0.04213144963144972 0.056877022653721666
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# True
# 39
# 13 0.9086578624078625 0.21659789644012942 0.05980958230958238 0.07390776699029125
# True
# 39
# 13 0.7918980343980344 0.2144093851132686 0.038943488943489 0.050857605177993516
# True
# 39
# 13 0.7014465601965602 0.20432038834951455 0.02829852579852576 0.03739482200647247
# True
# 39
# 23 0.9121007371007371 0.39177184466019416 0.12042997542997554 0.15101941747572814
# True
# 39
# 23 0.7425184275184277 0.2916949838187702 0.06158476658476658 0.07583333333333331
# True
# 39
# 23 0.6609428746928746 0.24974514563106795 0.04150491400491397 0.04953883495145633
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# True
# 39
# 1 0.9589987714987716 0.2773826860841424 0.026818181818181727 0.03389158576051783
# True
# 39
# 1 0.7109766584766584 0.26518203883495145 0.019791154791154807 0.028179611650485423
# True
# 39
# 1 0.5889649877149877 0.2601537216828479 0.018101965601965617 0.025987055016181232
# False
#
# False
#
# False
#
# True
# 39
# 19 0.8967628992628993 0.15665857605177994 0.037407862407862466 0.08851132686084143
# True
# 39
# 19 0.5326597051597052 0.16283576051779936 0.023759213759213728 0.06182038834951456
# True
# 39
# 19 0.34918611793611787 0.14764563106796116 0.020681818181818155 0.052847896440129445
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# True
# 39
# 0 0.9589465601965602 0.18679611650485436 0.052696560196560174 0.06496763754045307
# True
# 39
# 0 0.7626197788697789 0.18133899676375403 0.036025798525798444 0.046933656957928796
# True
# 39
# 0 0.6797297297297297 0.18394822006472494 0.0278746928746928 0.03744336569579288
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# True
# 39
# 2 0.9585841523341522 0.18562297734627833 0.05554668304668309 0.07889967637540454
# True
# 39
# 2 0.8448832923832923 0.19210355987055017 0.04162162162162161 0.05653721682847896
# True
# 39
# 2 0.7837469287469288 0.19446197411003238 0.033157248157248166 0.04338996763754047
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# True
# 40
# 39 0.9539926289926289 0.19135113268608414 0.08238329238329245 0.10247572815533978
# True
# 40
# 39 0.6634551597051597 0.19062297734627834 0.030595823095823062 0.03781553398058253
# True
# 40
# 39 0.6457585995085996 0.1906351132686084 0.026910319410319378 0.03324433656957929
# False
#
# False
#
# False
#
# True
# 40
# 9 0.9411148648648648 0.29388349514563106 0.08234029484029495 0.14475728155339807
# True
# 40
# 9 0.699198402948403 0.2348705501618123 0.03650491400491404 0.06868932038834952
# True
# 40
# 9 0.6267659705159705 0.22489077669902915 0.023384520884520914 0.04669093851132684
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# True
# 40
# 8 0.9752027027027028 0.1954368932038835 0.03898034398034386 0.06834951456310681
# True
# 40
# 8 0.8652917690417692 0.19364886731391584 0.027266584766584827 0.05323624595469256
# True
# 40
# 8 0.8195362407862408 0.19353964401294496 0.023593366093366142 0.04762944983818768
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# True
# 40
# 19 0.8824785012285014 0.21514563106796117 0.1502027027027027 0.26357605177993526
# True
# 40
# 19 0.6078531941031942 0.20372168284789646 0.07277027027027022 0.14140776699029126
# True
# 40
# 19 0.3512438574938575 0.21689724919093853 0.04918304668304671 0.09550970873786409
# True
# 40
# 9 0.9615509828009828 0.21469255663430423 0.05380221130221139 0.09428802588996762
# True
# 40
# 9 0.5676074938574939 0.20996763754045306 0.03324938574938575 0.06436893203883495
# True
# 40
# 9 0.39504299754299754 0.19148058252427186 0.025982800982800956 0.04974110032362461
# True
# 40
# 16 0.9189742014742014 0.20433252427184467 0.1510933660933661 0.1729692556634304
# True
# 40
# 16 0.6042598280098279 0.21033980582524273 0.052684275184275105 0.06176375404530742
# True
# 40
# 16 0.5581633906633907 0.1969336569579288 0.03511056511056509 0.041407766990291264
# True
# 40
# 13 0.9092444717444718 0.21856391585760515 0.15804668304668315 0.21544498381877025
# True
# 40
# 13 0.6737192874692876 0.1788915857605178 0.060964373464373466 0.08211974110032362
# True
# 40
# 13 0.630472972972973 0.18175970873786407 0.041793611793611844 0.05487864077669902
# True
# 40
# 13 0.047761056511056506 0.1512742718446602 0.05633292383292384 0.07008899676375405
# True
# 40
# 13 0.09653255528255528 0.1487257281553398 0.0498095823095823 0.06402103559870549
# False
#
# False
#
# True
# 40
# 13 0.9121775184275185 0.16301779935275082 0.10193488943488946 0.14344660194174755
# True
# 40
# 13 0.7671468058968058 0.17519417475728158 0.06396191646191653 0.08972491909385114
# True
# 40
# 13 0.7333323095823095 0.1798220064724919 0.05726658476658478 0.07938511326860842
# True
# 40
# 13 0.027856265356265356 0.20470873786407764 0.04113022113022113 0.05540453074433656
# True
# 40
# 13 0.21157248157248157 0.19913430420711975 0.025393120393120413 0.03446601941747572
# True
# 40
# 13 0.14101658476658477 0.2045266990291262 0.030853808353808347 0.04243527508090614
# True
# 40
# 19 0.8997542997542999 0.5244255663430422 0.14540540540540542 0.25409385113268607
# True
# 40
# 19 0.33482186732186736 0.31417071197411 0.05256756756756756 0.1037297734627832
# True
# 40
# 19 0.131262285012285 0.28079692556634306 0.03735257985257985 0.07127022653721686
# True
# 40
# 5 0.9221314496314497 0.24725728155339807 0.07684275184275179 0.09540453074433657
# True
# 40
# 5 0.7064619164619164 0.22425161812297736 0.04592137592137591 0.05534789644012945
# True
# 40
# 5 0.6038298525798527 0.22012135922330098 0.032647420147420135 0.03912621359223302
# False
#
# False
#
# False
#
# True
# 41
# 40 0.93002457002457 0.18694983818770225 0.11925061425061431 0.10896440129449841
# True
# 41
# 40 0.7323617936117935 0.19574029126213593 0.06796683046683039 0.06207928802588998
# True
# 41
# 40 0.6254269041769042 0.19628236245954694 0.04528869778869773 0.04177184466019419
# False
#
# False
#
# False
#
# True
# 42
# 41 0.9450552825552825 0.2560153721682848 0.06941031941031942 0.10194983818770226
# True
# 42
# 41 0.8541554054054055 0.268207928802589 0.0541461916461917 0.07903721682847896
# True
# 42
# 41 0.7882309582309582 0.24699838187702267 0.043206388206388294 0.06291262135922329
# False
#
# False
#
# False
#
# True
# 42
# 38 0.040138206388206386 0.23042071197411004 0.04704545454545455 0.05763754045307444
# True
# 42
# 38 0.1385012285012285 0.2354854368932039 0.03750614250614251 0.04733009708737864
# True
# 42
# 38 0.19164619164619165 0.25656148867313916 0.029361179361179334 0.04008090614886733
# True
# 42
# 9 0.9539312039312039 0.26592637540453073 0.05671990171990181 0.10240291262135927
# True
# 42
# 9 0.7850153562653563 0.2348948220064725 0.032659705159705066 0.06419093851132686
# True
# 42
# 9 0.7099815724815725 0.22561893203883496 0.023144963144963185 0.04588187702265375
# False
#
# False
#
# False
#
# True
# 42
# 9 0.9607094594594594 0.23386326860841425 0.06917076167076161 0.1348462783171521
# True
# 42
# 9 0.7457125307125307 0.2168972491909385 0.034852579852579856 0.07211165048543687
# True
# 42
# 9 0.6730896805896806 0.21205097087378644 0.02433660933660927 0.04838996763754046
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# True
# 42
# 9 0.9718273955773956 0.2802750809061489 0.04710687960687964 0.08394822006472491
# True
# 42
# 9 0.8159367321867322 0.24411407766990292 0.028114250614250602 0.052063106796116476
# True
# 42
# 9 0.7740601965601966 0.23360032362459549 0.02343980343980349 0.04341423948220067
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# True
# 42
# 9 0.9313206388206389 0.2513309061488673 0.05536855036855043 0.10292071197411004
# True
# 42
# 9 0.8962008599508599 0.2468163430420712 0.050288697788697864 0.09534789644012946
# True
# 42
# 9 0.7803255528255527 0.23127022653721685 0.03487714987714986 0.06802588996763753
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# True
# 42
# 4 0.9106818181818183 0.28489886731391584 0.1281449631449632 0.16274271844660193
# True
# 42
# 4 0.8211332923832922 0.2516788025889968 0.07586609336609336 0.10474919093851133
# True
# 42
# 4 0.7989711302211302 0.23247168284789643 0.05152948402948409 0.07643203883495145
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# True
# 42
# 0 0.04493550368550368 0.15227346278317153 0.022942260442260443 0.02977346278317153
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# True
# 42
# 0 0.9311578624078625 0.17882686084142393 0.08012899262899266 0.1077831715210356
# True
# 42
# 0 0.9286762899262899 0.18154935275080905 0.048298525798525865 0.061998381877022626
# True
# 42
# 0 0.8811640049140049 0.18708333333333335 0.05512899262899263 0.07059061488673139
# False
#
# False
#
# False
#
# True
# 43
# 42 0.9492199017199017 0.23447411003236246 0.06631449631449633 0.09637540453074434
# True
# 43
# 42 0.74870085995086 0.20895226537216827 0.037303439803439815 0.052322006472491925
# True
# 43
# 42 0.6821406633906635 0.20216828478964402 0.026996314496314525 0.036682847896440135
# False
#
# False
#
# False
#
# True
# 43
# 2 0.9366769041769041 0.22396035598705502 0.10375921375921367 0.14408576051779937
# True
# 43
# 2 0.7230773955773956 0.20619741100323627 0.05342751842751844 0.07194174757281552
# True
# 43
# 2 0.643980343980344 0.19421925566343043 0.03613022113022109 0.04745145631067962
# True
# 43
# 21 0.6866124078624077 0.18703883495145632 0.04114864864864865 0.049660194174757276
# True
# 43
# 21 0.9051382063882064 0.185165857605178 0.08931818181818187 0.11194983818770227
# True
# 43
# 21 0.7569625307125307 0.1899069579288026 0.056320638820638855 0.06987864077669906
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# True
# 43
# 2 0.6661148648648648 0.3188389967637541 0.04542383292383295 0.052532362459546934
# True
# 43
# 2 0.6133445945945947 0.29285194174757284 0.031246928746928748 0.03780744336569576
# True
# 43
# 2 0.9058875921375922 0.4798179611650486 0.09935503685503685 0.11796925566343047
# True
# 43
# 1 0.030611179361179363 0.3369660194174757 0.020104422604422606 0.027168284789644
# True
# 43
# 1 0.09317874692874692 0.31825242718446606 0.01625921375921376 0.022864077669902904
# True
# 43
# 1 0.14113636363636362 0.2983778317152103 0.014275184275184264 0.020088996763754034
# True
# 44
# 43 0.9125982800982801 0.17007686084142393 0.0992628992628992 0.12002427184466019
# True
# 44
# 43 0.7083722358722359 0.17553802588996764 0.049852579852579765 0.058810679611650485
# True
# 44
# 43 0.6383230958230959 0.1808818770226537 0.03190417690417694 0.03943365695792881
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# True
# 44
# 35 0.8609090909090908 0.2548503236245955 0.0559213759213759 0.10586569579288027
# True
# 44
# 35 0.7185534398034399 0.23220873786407767 0.03326167076167082 0.06504854368932037
# True
# 44
# 35 0.6659828009828008 0.22302993527508091 0.02503685503685503 0.04816343042071197
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# True
# 44
# 35 0.9314219901719902 0.14645631067961162 0.04593980343980342 0.08807443365695791
# True
# 44
# 35 0.7263513513513513 0.15829692556634303 0.022936117936118026 0.04771035598705502
# True
# 44
# 35 0.7939864864864864 0.1596601941747573 0.02979115479115479 0.05904530744336571
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# True
# 45
# 44 0.45799754299754303 0.39189320388349513 0.03901719901719901 0.053996763754045315
# True
# 45
# 44 0.8449477886977886 0.5363551779935275 0.06326167076167077 0.0908333333333334
# True
# 45
# 44 0.22469594594594594 0.3425 0.028114250614250602 0.03967637540453076
# True
# 46
# 45 0.8113636363636364 0.1280542071197411 0.1694471744471744 0.22039644012944987
# True
# 46
# 45 0.1764649877149877 0.1774029126213592 0.05865479115479114 0.07847896440129448
# True
# 46
# 45 0.3115847665847666 0.1688349514563107 0.07044226044226044 0.0943527508090615
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# True
# 46
# 12 0.7055558968058968 0.2106270226537217 0.04020270270270259 0.04876213592233013
# True
# 46
# 12 0.7151750614250615 0.2115776699029126 0.04286855036855035 0.05234627831715212
# True
# 46
# 12 0.72639742014742 0.21125000000000002 0.04575552825552826 0.05465210355987054
# False
#
# False
#
# False
#
# True
# 46
# 0 0.7682923832923833 0.1846440129449838 0.08848894348894346 0.11587378640776697
# True
# 46
# 0 0.7189097051597052 0.18930420711974108 0.07257371007371013 0.0953398058252427
# True
# 46
# 0 0.7413544226044225 0.1875566343042071 0.07886363636363629 0.10456310679611651
# True
# 47
# 46 0.9097051597051597 0.45907766990291266 0.0557002457002456 0.07694174757281555
# True
# 47
# 46 0.8417199017199019 0.4135153721682848 0.046265356265356224 0.06507281553398063
# True
# 47
# 46 0.7915325552825553 0.3824878640776699 0.0407432432432432 0.056464401294498354
# True
# 47
# 33 0.958968058968059 0.16895631067961164 0.0346928746928747 0.03865695792880259
# True
# 47
# 33 0.9216646191646192 0.1676415857605178 0.033144963144963166 0.03793689320388351
# True
# 47
# 33 0.7391277641277643 0.16227750809061486 0.027125307125307176 0.03143203883495145
# True
# 47
# 46 0.9532340294840295 0.24053398058252423 0.022254299754299767 0.028883495145631058
# True
# 47
# 46 0.9167137592137591 0.23726537216828478 0.021142506142506047 0.027734627831715188
# True
# 47
# 46 0.7367291154791155 0.22003236245954697 0.01654176904176894 0.022734627831715183
# True
# 47
# 19 0.5099723587223587 0.22282362459546923 0.03917076167076166 0.09349514563106796
# True
# 47
# 19 0.4148310810810811 0.20073624595469255 0.036664619164619196 0.08420711974110032
# True
# 47
# 46 0.8748740786240786 0.33678398058252423 0.034330466830466894 0.04830906148867312
# True
# 47
# 46 0.9063667076167077 0.3473745954692557 0.03808968058968058 0.050962783171521045
# True
# 47
# 46 0.9416707616707617 0.3585436893203883 0.04174447174447177 0.055145631067961186
# True
# 48
# 47 0.9793550368550368 0.1769700647249191 0.029459459459459342 0.05267799352750808
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# True
# 48
# 46 0.9601074938574937 0.27976132686084143 0.022487714987714926 0.028114886731391585
# True
# 48
# 46 0.9854330466830468 0.288838996763754 0.02410933660933661 0.02939320388349518
# True
# 48
# 46 0.9723740786240787 0.2850849514563107 0.021824324324324306 0.028826860841423944
# True
# 48
# 4 0.6684643734643735 0.12182443365695791 0.04606879606879607 0.08929611650485436
# True
# 48
# 4 0.715921375921376 0.12517394822006472 0.04770270270270261 0.09445792880258899
# True
# 48
# 4 0.7696990171990173 0.12830501618122975 0.04863636363636368 0.09939320388349514
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# True
# 48
# 46 0.8465878378378378 0.3304449838187702 0.034969287469287506 0.051019417475728156
# True
# 48
# 46 0.878943488943489 0.34254854368932036 0.03748157248157247 0.053996763754045315
# True
# 48
# 46 0.8182217444717444 0.3201577669902913 0.03347051597051598 0.04754854368932042
# True
# 48
# 46 0.8775614250614251 0.29466423948220066 0.02218673218673226 0.032192556634304224
# True
# 48
# 46 0.8577211302211302 0.28735032362459545 0.021437346437346353 0.031205501618122973
# True
# 48
# 46 0.8986701474201475 0.30103155339805826 0.02288083538083538 0.03277508090614886
# False
#
# False
#
# False
#
# True
# 49
# 48 0.7496621621621622 0.1790088996763754 0.05100737100737098 0.06832524271844662
# True
# 49
# 48 0.7754207616707617 0.17559466019417475 0.056124078624078554 0.07720873786407767
# True
# 49
# 48 0.7622051597051597 0.17752427184466021 0.05361179361179359 0.07289644012944986
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# True
# 49
# 22 0.9238697788697788 0.2627386731391586 0.1293611793611793 0.1679854368932039
# True
# 49
# 22 0.8897757985257985 0.2566949838187702 0.11821253071253074 0.15570388349514563
# True
# 50
# 49 0.6425214987714988 0.20230177993527507 0.030976658476658515 0.042855987055016156
# True
# 50
# 49 0.6403101965601965 0.2000687702265372 0.030190417690417675 0.041140776699029095
# True
# 50
# 49 0.566953316953317 0.20733009708737862 0.04008599508599508 0.055355987055016195
# False
#
# False
#
# False
#
# True
# 50
# 37 0.8548003685503686 0.233794498381877 0.06738943488943491 0.08352750809061488
# True
# 50
# 37 0.8857647420147421 0.23513754045307442 0.07292997542997544 0.09033980582524269
# True
# 50
# 37 0.8266922604422604 0.22661003236245952 0.05979729729729724 0.0768608414239482
# False
#
# False
#
# False
#
# True
# 50
# 42 0.785144348894349 0.10941343042071199 0.1805098280098281 0.2146197411003236
# True
# 50
# 42 0.8202886977886977 0.11467233009708737 0.20287469287469287 0.2209304207119741
# True
# 50
# 42 0.8586271498771499 0.11467233009708737 0.22843366093366085 0.2209304207119741
# False
#
# False
#
# False
#
# True
# 50
# 41 0.6165816953316954 0.37393608414239476 0.06254914004914007 0.08534789644012941
# True
# 50
# 41 0.6913175675675676 0.40009708737864075 0.07265970515970514 0.10014563106796115
# True
# 50
# 41 0.43216216216216213 0.3319296116504854 0.046793611793611765 0.06591423948220067
# True
# 50
# 36 0.8670792383292384 0.24831715210355984 0.043961916461916564 0.06899676375404533
# True
# 50
# 36 0.7727364864864864 0.24372168284789644 0.04116093366093366 0.06365695792880259
# True
# 50
# 36 0.6774846437346438 0.23391990291262135 0.03804054054054058 0.05790453074433659
# True
# 50
# 1 0.8656756756756756 0.33066343042071195 0.02432432432432427 0.03983818770226538
# True
# 50
# 1 0.6792014742014743 0.3033252427184466 0.022764127764127732 0.03490291262135926
# True
# 50
# 1 0.773046683046683 0.32031957928802585 0.023071253071253038 0.03614077669902914
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# True
# 50
# 1 0.2733753071253071 0.34093446601941746 0.029441031941031946 0.040881877022653744
# True
# 50
# 1 0.31037776412776413 0.3361367313915858 0.028937346437346446 0.03973300970873783
# True
# 50
# ...
# True
# 61
# 51 0.6860472972972973 0.19940129449838187 0.024097051597051607 0.034854368932038846
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# True
# 61
# 12 0.8572051597051596 0.16059466019417476 0.07730958230958239 0.09392394822006475
# True
# 61
# 12 0.7364742014742015 0.16682038834951457 0.05305896805896813 0.05993527508090614
# True
# 61
# 12 0.6717690417690417 0.17040857605177995 0.038783783783783846 0.0456391585760518
# True
# 61
# 2 0.8564557739557739 0.23311084142394822 0.0407125307125307 0.04821197411003239
# True
# 61
# 2 0.7367659705159705 0.21538025889967635 0.027549140049140133 0.03305825242718445
# True
# 61
# 2 0.672582923832924 0.20568365695792878 0.02027641277641277 0.02411812297734628
# True
# 61
# 6 0.7473157248157248 0.17467233009708735 0.05164619164619174 0.07727346278317151
# True
# 61
# 6 0.9091339066339067 0.1806148867313916 0.06163390663390658 0.09053398058252428
# True
# 61
# 6 0.4592168304668305 0.18876618122977346 0.038630221130221125 0.0552346278317152
# False
#
# False
#
# False
#
# True
# 61
# 6 0.9228624078624079 0.16558252427184467 0.09239557739557744 0.1283495145631068
# True
# 61
# 6 0.6847972972972972 0.17846278317152103 0.04404176904176907 0.05896440129449838
# True
# 61
# 6 0.7604391891891891 0.17350323624595468 0.058384520884520855 0.07995145631067962
# False
#
# False
#
# False
#
# True
# 61
# 16 0.9625429975429975 0.20769012944983817 0.06518427518427512 0.07044498381877025
# True
# 61
# 16 0.9350675675675676 0.15376618122977348 0.047063882063882 0.0541990291262136
# True
# 61
# 16 0.9425276412776412 0.22161003236245957 0.05548525798525794 0.06067961165048546
# True
# 61
# 22 0.9193028255528255 0.13399676375404532 0.11381449631449629 0.15110032362459547
# True
# 61
# 22 0.7947542997542998 0.15134304207119742 0.07797297297297287 0.10666666666666665
# True
# 61
# 22 0.7352733415233416 0.16377831715210356 0.06107493857493861 0.0827346278317152
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# True
# 61
# 6 0.9574907862407863 0.1972532362459547 0.042979115479115496 0.057758899676375396
# True
# 61
# 6 0.9022911547911547 0.20170307443365695 0.03601965601965608 0.04858414239482199
# False
#
# False
#
# True
# 61
# 34 0.9348587223587224 0.1944700647249191 0.037518427518427475 0.06659385113268607
# True
# 61
# 34 0.8716738329238329 0.19189320388349515 0.03146805896805898 0.05653721682847896
# True
# 61
# 34 0.8290479115479116 0.19142394822006473 0.02594594594594595 0.04959546925566344
# True
# 61
# 30 0.7981572481572482 0.05495550161812297 0.07475429975429979 0.10648058252427184
# True
# 61
# 30 0.7395853808353808 0.07518608414239483 0.06107493857493861 0.08640776699029128
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# True
# 61
# 27 0.972159090909091 0.23299352750809063 0.043323095823095806 0.04911003236245954
# True
# 61
# 27 0.9489619164619164 0.25792475728155334 0.10027027027027027 0.12334142394822005
# True
# 61
# 27 0.9281173218673218 0.23778721682847895 0.04941646191646194 0.05913430420711972
# False
#
# False
#
# False
#
# True
# 61
# 6 0.9613083538083538 0.2500404530744337 0.041855036855036776 0.054336569579288
# True
# 61
# 6 0.878605651105651 0.23786407766990292 0.0325798525798527 0.04244336569579291
# False
#
# False
#
# True
# 61
# 6 0.9685657248157247 0.2489118122977346 0.028925061425061373 0.03881067961165046
# True
# 61
# 6 0.9141308353808353 0.2434830097087379 0.024256756756756762 0.03251618122977346
# False
#
# False
#
# True
# 61
# 8 0.9525184275184275 0.24352750809061488 0.0344348894348894 0.06791262135922335
# True
# 61
# 8 0.8773095823095823 0.23819983818770224 0.028034398034397955 0.05644822006472495
# True
# 61
# 8 0.8230282555282554 0.22938106796116503 0.023390663390663487 0.04868122977346279
# True
# 61
# 2 0.890863022113022 0.4291545307443366 0.07243857493857497 0.10379449838187704
# True
# 61
# 2 0.36591523341523347 0.3011731391585761 0.034140049140049165 0.046213592233009713
# True
# 61
# 2 0.576661547911548 0.3470105177993527 0.05053439803439809 0.06813106796116503
# True
# 61
# 0 0.85372542997543 0.15274271844660192 0.056025798525798545 0.07346278317152105
# True
# 61
# 0 0.7986732186732187 0.15939320388349515 0.04793611793611791 0.061731391585760506
# True
# 61
# 0 0.9331357493857494 0.1429004854368932 0.0703009828009827 0.0921116504854369
# False
#
# False
#
# False
#
# True
# 61
# 16 0.8771498771498771 0.16676375404530744 0.13874692874692882 0.16990291262135923
# True
# 61
# 16 0.6927242014742016 0.18273058252427182 0.07345823095823091 0.08783980582524271
# True
# 61
# 16 0.6265786240786241 0.18429611650485436 0.04809582309582314 0.05629449838187701
# True
# 61
# 36 0.9295423832923834 0.1101779935275081 0.10767199017199015 0.143252427184466
# True
# 61
# 36 0.7157893120393121 0.1436003236245955 0.05209459459459456 0.07139158576051781
# True
# 61
# 36 0.788083538083538 0.1371116504854369 0.06972972972972973 0.09566343042071199
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# True
# 61
# 8 0.8902487714987716 0.2766140776699029 0.08123464373464373 0.15652912621359225
# True
# 61
# 8 0.7025460687960687 0.23438915857605178 0.03673832923832934 0.07138349514563105
# True
# 61
# 8 0.7612008599508601 0.21792071197411006 0.05095208845208848 0.09946601941747572
# False
#
# True
# 61
# 8 0.8796775184275184 0.30430016181229774 0.09972358722358717 0.18656148867313918
# True
# 61
# 8 0.7362223587223589 0.25599514563106796 0.05600737100737105 0.10946601941747573
# True
# 61
# 8 0.6732186732186732 0.23745145631067963 0.040110565110565224 0.07694174757281555
# False
#
# False
#
# False
#
# True
# 61
# 8 0.7999262899262899 0.24300161812297735 0.040945945945945854 0.07980582524271845
# True
# 61
# 8 0.9328562653562654 0.2634870550161812 0.06383292383292388 0.11898058252427185
# True
# 61
# 8 0.7305835380835382 0.23586974110032363 0.030712530712530713 0.05999190938511327
# False
#
# False
#
# False
#
# True
# 61
# 8 0.8015233415233416 0.2445186084142395 0.042874692874692845 0.08222491909385116
# True
# 61
# 8 0.9485104422604422 0.2737985436893204 0.06684889434889431 0.12183656957928801
# True
# 61
# 8 0.7014987714987715 0.22686893203883493 0.027235872235872326 0.05475728155339806
# False
#
# False
#
# False
#
# False
#
# False
#
# False
#
# True
# 61
# 46 0.9273710073710074 0.3077791262135922 0.036547911547911545 0.04649676375404528
# True
# 61
# 16 0.9369502457002458 0.26380258899676373 0.07695945945945944 0.09137540453074433
# True
# 61
# 16 0.7922911547911548 0.24528721682847893 0.055159705159705134 0.06659385113268608
# True
# 61
# 16 0.6855558968058968 0.23134708737864076 0.0430282555282555 0.05151294498381874
# True
# 61
# 4 0.9580681818181818 0.41817152103559874 0.06894963144963145 0.08750809061488679
# False
#
# False
#
# False
#
# False
#
# True
# 61
# 41 0.9049416461916461 0.22298543689320388 0.14607493857493867 0.19140776699029124
# True
# 61
# 7 0.9647358722358723 0.15211165048543687 0.031547911547911485 0.04705501618122977
# True
# 61
# 7 0.8223525798525798 0.1650566343042071 0.024705159705159723 0.033915857605177985
# True
# 61
# 7 0.7790141277641278 0.171128640776699 0.020190417690417763 0.030024271844660184
# True
# 61
# 11 0.9586793611793611 0.23683656957928803 0.06079852579852581 0.08860841423948221
# True
# 61
# 11 0.8207616707616708 0.22776699029126213 0.046461916461916386 0.06647249190938513
# True
# 61
# 11 0.777146805896806 0.22576860841423949 0.03994471744471743 0.058495145631067946
# True
# 61
# 16 0.9082954545454545 0.1678640776699029 0.1266891891891892 0.171084142394822
# True
# 61
# 16 0.27157555282555285 0.16551375404530744 0.06570638820638822 0.08118932038834951
# True
# 61
# 7 0.9605896805896806 0.18605582524271844 0.031068796068796162 0.037160194174757286
# True
# 61
# 7 0.8923832923832925 0.18706715210355987 0.026007371007370956 0.03164239482200648
# True
# 61
# 7 0.8414066339066338 0.1864967637540453 0.021670761670761655 0.027734627831715212
# True
# 61
# 46 0.9576412776412776 0.2275687702265372 0.03374692874692878 0.04068770226537218
# True
# 61
# 46 0.8908445945945946 0.2231472491909385 0.028482800982801055 0.03409385113268607
# True
# 61
# 46 0.8403562653562653 0.21773058252427185 0.023280098280098197 0.029846278317152114
# True
# 61
# 12 0.6970116707616708 0.038216019417475725 0.06204545454545454 0.07317961165048542
# True
# 61
# 12 0.6244502457002458 0.09194983818770226 0.03928132678132674 0.046100323624595464
# True
# 61
# 12 0.6535350122850122 0.07142394822006473 0.04684889434889434 0.05673139158576052
# False
#
# False
#
# False
#
# True
# 61
# 7 0.9697328009828009 0.1777588996763754 0.028703931203931214 0.03859223300970873
# True
# 61
# 7 0.8747174447174447 0.17940938511326862 0.022911547911547883 0.03033980582524272
# True
# 61
# 46 0.8737254299754301 0.2134546925566343 0.02489557739557738 0.03262135922330099
# True
# 61
# 46 0.9666891891891892 0.2222411003236246 0.031081081081081024 0.04250809061488672
# True
# 61
# 4 0.9228347665847666 0.18690129449838186 0.05243857493857487 0.06624595469255663
# False
#
# True
# 61
# 7 0.9736210073710074 0.1954813915857605 0.041357493857493814 0.0524514563106796
# True
# 61
# 46 0.9694256756756756 0.2581229773462783 0.04589066339066341 0.05855987055016181
# False
#
# False
#
# False
#
# True
# 61
# 46 0.27640970515970514 0.3484142394822006 0.018691646191646195 0.039304207119741086
# True
# 61
# 46 0.9262776412776413 0.40590210355987055 0.026117936117936107 0.06741909385113272
# True
# 61
# 46 0.5833108108108108 0.3541949838187702 0.021928746928746957 0.049506472491909384
# True
# 61
# 8 0.8894656019656021 0.2819781553398058 0.1015110565110565 0.17620550161812298
# True
# 61
# 8 0.5524170761670761 0.2346440129449838 0.04937960687960687 0.09597087378640774
# True
# 61
# 8 0.9209643734643734 0.27849919093851133 0.0754668304668304 0.13869741100323627
# True
# 61
# 8 0.8148925061425061 0.2431148867313916 0.046369778869778874 0.08962783171521035
# True
# 61
# 8 0.9156296068796068 0.30877427184466016 0.10225429975429977 0.16324433656957926
# True
# 61
# 8 0.7359029484029483 0.25760113268608414 0.049078624078624136 0.09439320388349516
# True
# 61
# 8 0.6303562653562653 0.23301375404530744 0.03300982800982795 0.05999190938511325
# False
#
# False
#
# False
#
# True
# 61
# 8 0.7039680589680589 0.2272532362459547 0.04154791154791161 0.08138349514563108
# True
# 61
# 8 0.6550737100737101 0.21866909385113267 0.030503685503685415 0.06054207119741099
# True
# 61
# 8 0.9098863636363637 0.26949433656957933 0.08910933660933656 0.1714967637540453
# False
#
# False
#
# False
#
# True
# 61
# 7 0.8552487714987713 0.23602346278317154 0.07460073710073713 0.09630258899676375
# True
# 61
# 7 0.9343181818181819 0.2569700647249191 0.12025798525798524 0.1540210355987055
# True
# 61
# 7 0.8748894348894349 0.24456310679611648 0.09138820638820637 0.11699029126213592
# True
# 61
# 46 0.9258691646191647 0.37102346278317155 0.056283783783783854 0.07041262135922333
# True
# 61
# 46 0.8506787469287469 0.30898867313915857 0.03553439803439798 0.04444983818770226
# True
# 61
# 46 0.8696498771498772 0.33308252427184465 0.0432309582309583 0.05440129449838189
# True
# 61
# 7 0.9469287469287468 0.11155339805825243 0.035171990171990165 0.04444983818770226
# True
# 61
# 7 0.907039312039312 0.12080906148867314 0.029299754299754326 0.03757281553398058
# True
# 61
# 7 0.8287530712530713 0.1407564724919094 0.020958230958230892 0.027742718446601936
# True
# 61
# 11 0.9053132678132677 0.1779733009708738 0.05705159705159698 0.0734546925566343
# True
# 61
# 11 0.944465601965602 0.17710760517799354 0.06749385749385742 0.08279126213592232
# True
# 61
# 11 0.828458230958231 0.181747572815534 0.04036855036855039 0.05221682847896442
# ['camera00\\image.004472.jpg', 'camera00\\image.005430.jpg', 'camera00\\image.002373.jpg', 'camera00\\image.006482.jpg', 'camera00\\image.007134.jpg', 'camera00\\image.007436.jpg', 'camera00\\image.006102.jpg', 'camera00\\image.008762.jpg', 'camera00\\image.001351.jpg', 'Bochum\\images\\Bochum\\DE_BBBR667_2015-04-21_17-32-08-884012_k0.jpg', 'camera00\\image.008519.jpg', 'camera00\\image.000024.jpg', 'camera00\\image.001501.jpg', 'camera00\\image.007495.jpg', 'camera00\\image.008302.jpg', 'camera00\\image.004702.jpg', 'camera00\\image.005434.jpg', 'camera00\\image.003109.jpg', 'camera00\\image.002200.jpg', 'camera00\\image.005506.jpg', 'camera00\\image.008490.jpg', 'camera00\\image.004353.jpg', 'camera00\\image.003786.jpg', 'camera00\\image.000746.jpg', 'camera00\\image.006308.jpg', 'camera00\\image.008318.jpg', 'camera00\\image.003204.jpg', 'camera00\\image.004097.jpg', 'camera00\\image.001059.jpg', 'camera00\\image.003744.jpg', 'camera00\\image.007195.jpg', 'camera00\\image.008208.jpg', 'camera00\\image.001775.jpg', 'camera00\\image.007318.jpg', 'camera00\\image.001880.jpg', 'camera00\\image.002799.jpg', 'camera00\\image.006615.jpg', 'camera00\\image.006840.jpg', 'camera00\\image.008697.jpg', 'camera00\\image.006607.jpg', 'camera00\\image.008860.jpg', 'Bochum\\images\\Bochum\\DE_BBBR667_2015-04-21_17-15-33-286844_k0.jpg', 'Bochum\\images\\Bochum\\DE_BBBR667_2015-04-21_17-15-44-284264_k0.jpg', 'camera00\\image.003922.jpg', 'camera00\\image.002435.jpg', 'camera00\\image.002196.jpg', 'Bochum\\images\\Bochum\\DE_BBBR667_2015-04-21_17-14-12-686374_k0.jpg', 'camera00\\image.004007.jpg', 'camera00\\image.007757.jpg', 'Bochum\\images\\Bochum\\DE_BBBR667_2015-04-21_17-24-18-490002_k0.jpg', 'Bochum\\images\\Bochum\\DE_BBBR667_2015-04-21_17-34-35-148543_k0.jpg', 'camera00\\image.007279.jpg', 'camera00\\image.007982.jpg', 'camera00\\image.008063.jpg', 'camera00\\image.005398.jpg', 'camera00\\image.006857.jpg', 'Bochum\\images\\Bochum\\DE_BBBR667_2015-04-21_17-34-38-881924_k0.jpg', 'camera00\\image.000445.jpg', 'camera00\\image.002640.jpg', 'camera00\\image.007952.jpg', 'camera00\\image.005512.jpg', 'Bochum\\images\\Bochum\\DE_BBBR667_2015-04-21_17-15-36-617761_k0.jpg', 'camera00\\image.005357.jpg', 'camera00\\image.002369.jpg', 'camera00\\image.002472.jpg', 'camera00\\image.000318.jpg', 'camera00\\image.000957.jpg', 'camera00\\image.007146.jpg', 'camera00\\image.002311.jpg', 'camera00\\image.008394.jpg', 'camera00\\image.007471.jpg', 'Bochum\\images\\Bochum\\DE_BBBR667_2015-04-21_17-24-35-684243_k0.jpg', 'camera00\\image.002134.jpg', 'camera00\\image.005577.jpg', 'camera00\\image.008808.jpg', 'camera00\\image.007073.jpg', 'camera00\\image.004668.jpg', 'camera00\\image.005711.jpg', 'camera00\\image.002229.jpg', 'camera00\\image.004056.jpg', 'camera00\\image.008912.jpg', 'camera00\\image.002391.jpg', 'camera00\\image.003728.jpg', 'camera00\\image.002751.jpg', 'camera00\\image.004561.jpg', 'camera00\\image.008388.jpg', 'camera00\\image.000062.jpg', 'camera00\\image.005625.jpg', 'camera00\\image.002073.jpg', 'camera00\\image.005602.jpg', 'Bochum\\images\\Bochum\\DE_BBBR667_2015-04-21_17-23-50-483940_k0.jpg', 'Bochum\\images\\Bochum\\DE_BBBR667_2015-04-21_17-11-22-950387_k0.jpg', 'camera00\\image.002669.jpg', 'camera00\\image.008859.jpg', 'camera00\\image.005327.jpg', 'camera00\\image.001252.jpg', 'camera00\\image.004743.jpg', 'camera00\\image.002189.jpg', 'camera00\\image.002872.jpg', 'camera00\\image.002780.jpg', 'camera00\\image.006925.jpg', 'camera00\\image.002187.jpg', 'camera00\\image.006706.jpg', 'camera00\\image.007343.jpg', 'Bochum\\images\\Bochum\\DE_BBBR667_2015-04-21_17-28-51-886794_k0.jpg', 'camera00\\image.007788.jpg', 'camera00\\image.008701.jpg', 'camera00\\image.004370.jpg', 'camera00\\image.007884.jpg', 'camera00\\image.001120.jpg', 'camera00\\image.005661.jpg', 'camera00\\image.002723.jpg', 'camera00\\image.008685.jpg', 'camera00\\image.004916.jpg', 'camera00\\image.008386.jpg', 'camera00\\image.008764.jpg', 'Bochum\\images ...
# FileNotFoundError: [Errno 2] No such file or directory: 'camera00\\image.001252.txt'
# FileNotFoundError: [Errno 2] No such file or directory: 'camera00\\image.006925.txt'
# FileNotFoundError: [Errno 2] No such file or directory: 'camera00\\image.006934.txt'
# FileNotFoundError: [Errno 2] No such file or directory: 'camera00\\image.006544.txt'
# FileNotFoundError: [Errno 2] No such file or directory: 'camera00\\image.006543.txt'
# FileNotFoundError: [Errno 2] No such file or directory: 'camera00\\image.006935.txt'
# FileNotFoundError: [Errno 2] No such file or directory: 'camera00\\image.000192.txt'
# FileNotFoundError: [Errno 2] No such file or directory: 'camera00\\image.001250.txt'
# FileNotFoundError: [Errno 2] No such file or directory: 'camera00\\image.006926.txt'
# FileNotFoundError: [Errno 2] No such file or directory: 'camera00\\image.000191.txt'
# FileNotFoundError: [Errno 2] No such file or directory: 'camera00\\image.006924.txt'
# FileNotFoundError: [Errno 2] No such file or directory: 'camera00\\image.006933.txt'
# YOLO format annotations have been saved to combined_yolo_annotations.
# YAML file has been generated as data.yaml.
